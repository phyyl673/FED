# %%
# %%
from fed.data import load_gdp_data, clean_gdp_data
from fed.plot_utils import plot_gdp_trends

# %%
csv_path = "fed/gdp_whole.csv"
df_raw = load_gdp_data(filepath=csv_path)
df_raw.head()

# %%
df_clean = clean_gdp_data(df_raw, fill_method="interpolate", save_path="fed/data_clean.csv")

plot_gdp_trends(df_clean)
# Out:
# Loaded GDP data for 7 countries (2000–2022) from gdp_whole.csv
#  Cleaned data saved to C:\Users\Bronny\FED\fed\data_clean.csv

# %% [markdown]
# From the chart, it is clear that the United States has consistently maintained the highest GDP from 2000 to 2022, showing substantial and steady growth over the years. China’s GDP experienced remarkable expansion during this period, rising from fifth place in 2000 to second place after 2020, significantly outperforming the other countries while remaining behind the United States.
#
# The GDP of other countries remained relatively stable with only minor fluctuations. Japan consistently ranked between second and third place, Germany between third and fourth, and the United Kingdom between fourth and fifth. Brazil and Switzerland had comparatively lower GDP levels, staying in sixth and seventh place respectively, with little overall change.
